# %% [markdown]
# # Mobile Image Preparation

# %%
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image 
import numpy as np
import os
# from model_selection import CNNModel

# %% [markdown]
# ### Image Preparation: Tasks
#
# 1. Image Processing
# 2. Data Augmentation
# 3. Image Manipulation
# 4. Image Visualisation

# %% [markdown]
# ## Image Processing

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image

# %%
# create constrants for images of training and testing set
train_path = "D:\\Machine_Learning\\Portfolio_Project_Machine_Learning\\Mobile_Phone_Recognition\\mobile_phone_images\\train_images"
test_path = "D:\\Machine_Learning\\Portfolio_Project_Machine_Learning\\Mobile_Phone_Recognition\\mobile_phone_images\\test_images"

# split training and testing images
img_trainset = os.listdir(train_path)
img_testset = os.listdir(test_path)
trainset_size = len(img_trainset)
testset_size = len(img_testset)
img_size_tot = trainset_size+testset_size

image_size = (224,224)
batch_size = 32
# create labels for these images 
mobile_brands = []
print(f"Training images: {trainset_size} with ({trainset_size/img_size_tot:.2f})")
print(f"Testing images: {len(img_testset)} with ({testset_size/img_size_tot:.2f})")
# Out:
# Training images: 623 with (0.80)
# Testing images: 153 with (0.20)

# %% [markdown]
# Tasks for image processing:
# + Classifying images into their labels
# + Applying fixed size for all images

# %%
# create instance of ImageDataGenerator --> augmentation of images
datagen = ImageDataGenerator(
  rotation_range = 40,
  width_shift = 0.2,
  height_shift = 0.2,
  shear_range = 0.2,
  zoom_range = 0.2,
  horizontal_flip = True,
  fill_mode = 'nearest'
)

# load a sample image and reshape it
img = image.load_img()
