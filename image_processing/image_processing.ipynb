# %% [markdown]
# # Image Processing: Mobile Phones

# %%
# import libraries for data processing
import numpy as np
import pandas as pd
import cv2 as cv 
import os 

# import tools for processing images
from image_processing_tools import construct_feature, rename_images

# %% [markdown]
# ### ML Approach: Image Processing

# %% [markdown]
# + Reorganisation of images
# + Image Preprocessing
# + Image Conversion in 3D arrays
# + Reorganisation images
# + Imagery Analysis

# %% [markdown]
# ## Reorganisation of images

# %% [markdown]
# Approach:
# + rename the image files using numeric names with format ("image_{index}.jpg)
# + create new class folders for training model with images

# %%
path = "D:\\Machine_Learning\\Portfolio_Project_Machine_Learning\\Mobile_Phone_Recognition\\mobile_phone_images\\mobile_images_v2"
image_files = os.listdir(path)
image_files[:5]
# Out:
# ['smartphone_0.jpg',
#  'smartphone_1.jpg',
#  'smartphone_10.jpg',
#  'smartphone_100.jpg',
#  'smartphone_101.jpg']

# %%
# rename the image files 
rename_images(path=path, 
              img_file_list=image_files)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 # rename the image files
# ----> 2 rename_images(path=path,
#       3               img_file_list=image_files)
#
# File d:\Machine_Learning\Portfolio_Project_Machine_Learning\Mobile_Phone_Recognition\image_processing\image_processing_tools.py:27, in rename_images(path, img_file_list)
#      24   temp_path = os.path.join(path, temp_filename)
#      26   # rename to temprary filename
# ---> 27   os.rename(old_path, temp_path)
#      29 # update list of files after first renaming
#      30 temp_file_list = os.listdir(path)
#
# ...

# %% [markdown]
# ## Image Conversion

# %% [markdown]
# ## Reorganisation images

# %% [markdown]
# Approach:
# + returning number of images per folder
# + creating new class folders

# %%
# creating new class folders
