# %% [markdown]
# ## Image Extraction: Amazon Link Page 2

# %%
# import libraries for system configuration
import os
import sys
import warnings

# import dependencies for data processing and visualisation
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# ### Approach: Image Extraction
#
# + Data Loading
# + System Configuration: WebDriver for Edge Browser
# + Collecting Images from Amazon Web page: Downloading Process
# + Renaming image items with new filenames
# + Store image path into DataFrame

# %% [markdown]
# ## Data Loading

# %%
# Load amazon link dataset
amazon_ds = pd.read_csv("amazon_links2.csv")
amazon_ds.head()
# Out:
#                                                links
# 0  https://www.amazon.com.be/-/en/s?i=electronics...
# 1  https://www.amazon.com.be/-/en/s?i=electronics...
# 2  https://www.amazon.com.be/-/en/s?i=electronics...
# 3  https://www.amazon.com.be/-/en/s?i=electronics...
# 4  https://www.amazon.com.be/-/en/s?i=electronics...

# %%
print(f"Number of links: {amazon_ds.shape[0]}")
# Out:
# Number of links: 52

# %% [markdown]
# ## System Configuration: WebDriver for Edge Browser

# %%
# Import dependencies for extracting images
from selenium import webdriver
from selenium.webdriver.edge.options import Options
from selenium.webdriver.edge.service import Service
from selenium.webdriver.common.by import By

# %%
# Setup environment for WebDriver on Edge Browser
options = Options()
options.add_argument("--headless")

# Setup WebDriver service 
edgedriver_path = "D:\\Data_Engineering\\data_extraction\\msedgedriver.exe"
service = Service(executable_path=edgedriver_path)

driver = webdriver.Edge(options=options, service=service)

# %% [markdown]
# ## Data Collection: Downloading images from Amazon

# %%
# Import dependencies for downloading images
import requests

# %% [markdown]
# The Data Collection process involves several steps of gathering image content for training neural network models. To implement this stage, 2 cases need to be considered. Test Case and Full Case.
#
# The test case assumes 3 URLS extracted from Amazon. This is to get more control on how the images are extracted during the processes. The sequences of images provides more insight about the distribution of the images for every URLs from which the images are downloaded. The full case requires all requested URLs to make a complete image extraction for this stage. This allows more managability of manipulating and storing these images.
#
# This stage entails 2 processes to complete the collection process of images:
# + Extration process: with iteration loop
# + Downloading process

# %% [markdown]
# ### Extraction Process: with Iteration loop

# %%
# Extract images from each amazon links
def extract_images(webdriver, link, class_attr = "s-image") -> list:
    # Retrieve URLS    
    webdriver.get(link)
    img_elements = webdriver.find_elements(By.CLASS_NAME, class_attr)
    image_urls = [web_elem.get_attribute("src") for web_elem in img_elements]
    return image_urls

# %%
# Define functions for: iteration process of image extraction && downloading process
# Function 1: Iteration Image Process
def iteration_image_process(dataset):
    # Define constants
    links = dataset["links"].values
    item_img_lst = []
    items_tot = 0

    # Iterate over a list of links --> extract images 
    for i, link in enumerate(links):
        # Extract images from each amazon weblink + determine the number of images per url
        img_seq = extract_images(webdriver=driver, link=link)
        seq_size = len(img_seq)

        # Store image items into a list + determine the total number of images for the entire list
        item_img_lst.append(img_seq)
        items_tot += seq_size
        print(f"Amazon URL {i + 1}: {seq_size} items (successfully extracted)")
    print(f"Image Extraction is completed. Number of Image URLs: {items_tot} ")
    img_list = [item for item_seq in item_img_lst for item in item_seq]
    return img_list

# %%
# Extract all the images from URLs
img_urls = iteration_image_process(amazon_ds)
img_urls[:3]
# Out:
# Amazon URL 1: 2 items (successfully extracted)
# Amazon URL 2: 2 items (successfully extracted)
# Amazon URL 3: 24 items (successfully extracted)
# Amazon URL 4: 24 items (successfully extracted)
# Amazon URL 5: 24 items (successfully extracted)
# Amazon URL 6: 24 items (successfully extracted)
# Amazon URL 7: 24 items (successfully extracted)
# Amazon URL 8: 24 items (successfully extracted)
# Amazon URL 9: 24 items (successfully extracted)
# Amazon URL 10: 24 items (successfully extracted)
# Amazon URL 11: 24 items (successfully extracted)
# Amazon URL 12: 24 items (successfully extracted)
# Amazon URL 13: 24 items (successfully extracted)
# Amazon URL 14: 24 items (successfully extracted)
# Amazon URL 15: 24 items (successfully extracted)
# Amazon URL 16: 24 items (successfully extracted)
# Amazon URL 17: 24 items (successfully extracted)
# Amazon URL 18: 24 items (successfully extracted)
# Amazon URL 19: 10 items (successfully extracted)
# Amazon URL 20: 24 items (successfully extracted)
# Amazon URL 21: 24 items (successfully extracted)
# Amazon URL 22: 22 items (successfully extracted)
# Amazon URL 23: 9 items (successfully extracted)
# Amazon URL 24: 24 items (successfully extracted)
# Amazon URL 25: 24 items (successfully extracted)
# Amazon URL 26: 17 items (successfully extracted)
# Amazon URL 27: 24 items (successfully extracted)
# Amazon URL 28: 24 items (successfully extracted)
# Amazon URL 29: 24 items (successfully extracted)
# Amazon URL 30: 24 items (successfully extracted)
# Amazon URL 31: 24 items (successfully extracted)
# Amazon URL 32: 24 items (successfully extracted)
# Amazon URL 33: 24 items (successfully extracted)
# Amazon URL 34: 11 items (successfully extracted)
# Amazon URL 35: 24 items (successfully extracted)
# Amazon URL 36: 24 items (successfully extracted)
# Amazon URL 37: 20 items (successfully extracted)
# Amazon URL 38: 24 items (successfully extracted)
# Amazon URL 39: 11 items (successfully extracted)
# Amazon URL 40: 24 items (successfully extracted)
# Amazon URL 41: 24 items (successfully extracted)
# Amazon URL 42: 24 items (successfully extracted)
# Amazon URL 43: 24 items (successfully extracted)
# Amazon URL 44: 24 items (successfully extracted)
# Amazon URL 45: 24 items (successfully extracted)
# Amazon URL 46: 24 items (successfully extracted)
# Amazon URL 47: 24 items (successfully extracted)
# Amazon URL 48: 0 items (successfully extracted)
# Amazon URL 49: 0 items (successfully extracted)
# Amazon URL 50: 0 items (successfully extracted)
# Amazon URL 51: 24 items (successfully extracted)
# Amazon URL 52: 24 items (successfully extracted)
# Image Extraction is completed. Number of Image URLs: 1064
# ['https://m.media-amazon.com/images/I/81+nVRqtvgL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/61JoakEHUbL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71nKFUWbTvL._AC_UL320_.jpg']

# %% [markdown]
# ### Download Process: retrieving images from URLs

# %%
# Define function for: download process
# Function 2: Downloading process
def downloading_process(image_urls, path):
    # Folder to save images
    save_folder = "images"
    save_path = os.path.join(path, save_folder)

    # Create the folder if it doesn't exist
    os.makedirs(save_folder, exist_ok=True)

    # Download and save each image
    for i, url in enumerate(image_urls, start=1):
        try:
            response = requests.get(url, stream=True)
            response.raise_for_status()  # Check if the request was successful

            # Save the image to the folder
            file_extension = url.split(".")[-1]  # Get the file extension
            file_name = f"image_{i}.{file_extension}"
            file_path = os.path.join(save_path, file_name)

            with open(file_path, "wb") as file:
                for chunk in response.iter_content(1024):
                    file.write(chunk)
            
            print(f"Downloaded image {i}: {file_name}")
        except requests.exceptions.RequestException as e:
            print(f"Failed to download {url}: {e}")

# %%
len(img_urls)
# Out:
# 1064

# %%
# Download all the images from image URLS in folder called "image"
path = "D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\coll
# Downloaded image 777: image_777.jpg
# Downloaded image 778: image_778.jpg
# Downloaded image 779: image_779.jpg
# Downloaded image 780: image_780.jpg
# Downloaded image 781: image_781.jpg
# Downloaded image 782: image_782.jpg
# Downloaded image 783: image_783.jpg
# Downloaded image 784: image_784.jpg
# Downloaded image 785: image_785.jpg
# Downloaded image 786: image_786.jpg
# Downloaded image 787: image_787.jpg
# Downloaded image 788: image_788.jpg
# Downloaded image 789: image_789.jpg
# Downloaded image 790: image_790.jpg
# Downloaded image 791: image_791.jpg
# Downloaded image 792: image_792.jpg
# Downloaded image 793: image_793.jpg
# Downloaded image 794: image_794.jpg
# Downloaded image 795: image_795.jpg
# Downloaded image 796: image_796.jpg
# Downloaded image 797: image_797.jpg
# Downloaded image 798: image_798.jpg
# Downloaded image 799: image_799.jpg
# Downloaded image 800: image_800.jpg
# Downloaded image 801: image_801.jpg
# Downloaded image 802: image_802.jpg
# Downloaded image 803: image_803.jpg
# Downloaded image 804: image_804.jpg
# Downloaded image 805: image_805.jpg
# Downloaded image 806: image_806.jpg
# Downloaded image 807: image_807.jpg
# Downloaded image 808: image_808.jpg
# Downloaded image 809: image_809.jpg
# Downloaded image 810: image_810.jpg
# Downloaded image 811: image_811.jpg
# Downloaded image 812: image_812.jpg
# Downloaded image 813: image_813.jpg
# Downloaded image 814: image_814.jpg
# Downloaded image 815: image_815.jpg
# Downloaded image 816: image_816.jpg
# Downloaded image 817: image_817.jpg
# Downloaded image 818: image_818.jpg
# Downloaded image 819: image_819.jpg
# Downloaded image 820: image_820.jpg
# Downloaded image 821: image_821.jpg
# Downloaded image 822: image_822.jpg
# Downloaded image 823: image_823.jpg
# Downloaded image 824: image_824.jpg
# Downloaded image 825: image_825.jpg
# Downloaded image 826: image_826.jpg
# Downloaded image 827: image_827.jpg
# Downloaded image 828: image_828.jpg
# Downloaded image 829: image_829.jpg
# Downloaded image 830: image_830.jpg
# Downloaded image 831: image_831.jpg
# Downloaded image 832: image_832.jpg
# Downloaded image 833: image_833.jpg
# Downloaded image 834: image_834.jpg
# Downloaded image 835: image_835.jpg
# Downloaded image 836: image_836.jpg
# Downloaded image 837: image_837.jpg
# Downloaded image 838: image_838.jpg
# Downloaded image 839: image_839.jpg
# Downloaded image 840: image_840.jpg
# Downloaded image 841: image_841.jpg
# Downloaded image 842: image_842.jpg
# Downloaded image 843: image_843.jpg
# Downloaded image 844: image_844.jpg
# Downloaded image 845: image_845.jpg
# Downloaded image 846: image_846.jpg
# Downloaded image 847: image_847.jpg
# Downloaded image 848: image_848.jpg
# Downloaded image 849: image_849.jpg
# Downloaded image 850: image_850.jpg
# Downloaded image 851: image_851.jpg
# Downloaded image 852: image_852.jpg
# Downloaded image 853: image_853.jpg
# Downloaded image 854: image_854.jpg
# Downloaded image 855: image_855.jpg
# Downloaded image 856: image_856.jpg
# Downloaded image 857: image_857.jpg
# Downloaded image 858: image_858.jpg
# Downloaded image 859: image_859.jpg
# Downloaded image 860: image_860.jpg
# Downloaded image 861: image_861.jpg
# Downloaded image 862: image_862.jpg
# Downloaded image 863: image_863.jpg
# Downloaded image 864: image_864.jpg
# Downloaded image 865: image_865.jpg
# Downloaded image 866: image_866.jpg
# Downloaded image 867: image_867.jpg
# Downloaded image 868: image_868.jpg
# Downloaded image 869: image_869.jpg
# Downloaded image 870: image_870.jpg
# Downloaded image 871: image_871.jpg
# Downloaded image 872: image_872.jpg
# Downloaded image 873: image_873.jpg
# Downloaded image 874: image_874.jpg
# Downloaded image 875: image_875.jpg
# Downloaded image 876: image_876.jpg
# Downloaded image 877: image_877.jpg
# Downloaded image 878: image_878.jpg
# Downloaded image 879: image_879.jpg
# Downloaded image 880: image_880.jpg
# Downloaded image 881: image_881.jpg
# Downloaded image 882: image_882.jpg
# Downloaded image 883: image_883.jpg
# Downloaded image 884: image_884.jpg
# Downloaded image 885: image_885.jpg
# Downloaded image 886: image_886.jpg
# Downloaded image 887: image_887.jpg
# Downloaded image 888: image_888.jpg
# Downloaded image 889: image_889.jpg
# Downloaded image 890: image_890.jpg
# Downloaded image 891: image_891.jpg
# Downloaded image 892: image_892.jpg
# Downloaded image 893: image_893.jpg
# Downloaded image 894: image_894.jpg
# Downloaded image 895: image_895.jpg
# Downloaded image 896: image_896.jpg
# Downloaded image 897: image_897.jpg
# Downloaded image 898: image_898.jpg
# Downloaded image 899: image_899.jpg
# Downloaded image 900: image_900.jpg
# Downloaded image 901: image_901.jpg
# Downloaded image 902: image_902.jpg
# Downloaded image 903: image_903.jpg
# Downloaded image 904: image_904.jpg
# Downloaded image 905: image_905.jpg
# Downloaded image 906: image_906.jpg
# Downloaded image 907: image_907.jpg
# Downloaded image 908: image_908.jpg
# Downloaded image 909: image_909.jpg
# Downloaded image 910: image_910.jpg
# Downloaded image 911: image_911.jpg
# Downloaded image 912: image_912.jpg
# Downloaded image 913: image_913.jpg
# Downloaded image 914: image_914.jpg
# Downloaded image 915: image_915.jpg
# Downloaded image 916: image_916.jpg
# Downloaded image 917: image_917.jpg
# Downloaded image 918: image_918.jpg
# Downloaded image 919: image_919.jpg
# Downloaded image 920: image_920.jpg
# Downloaded image 921: image_921.jpg
# Downloaded image 922: image_922.jpg
# Downloaded image 923: image_923.jpg
# Downloaded image 924: image_924.jpg
# Downloaded image 925: image_925.jpg
# Downloaded image 926: image_926.jpg
# Downloaded image 927: image_927.jpg
# Downloaded image 928: image_928.jpg
# Downloaded image 929: image_929.jpg
# Downloaded image 930: image_930.jpg
# Downloaded image 931: image_931.jpg
# Downloaded image 932: image_932.jpg
# Downloaded image 933: image_933.jpg
# Downloaded image 934: image_934.jpg
# Downloaded image 935: image_935.jpg
# Downloaded image 936: image_936.jpg
# Downloaded image 937: image_937.jpg
# Downloaded image 938: image_938.jpg
# Downloaded image 939: image_939.jpg
# Downloaded image 940: image_940.jpg
# Downloaded image 941: image_941.jpg
# Downloaded image 942: image_942.jpg
# Downloaded image 943: image_943.jpg
# Downloaded image 944: image_944.jpg
# Downloaded image 945: image_945.jpg
# Downloaded image 946: image_946.jpg
# Downloaded image 947: image_947.jpg
# Downloaded image 948: image_948.jpg
# Downloaded image 949: image_949.jpg
# Downloaded image 950: image_950.jpg
# Downloaded image 951: image_951.jpg
# Downloaded image 952: image_952.jpg
# Downloaded image 953: image_953.jpg
# Downloaded image 954: image_954.jpg
# Downloaded image 955: image_955.jpg
# Downloaded image 956: image_956.jpg
# Downloaded image 957: image_957.jpg
# Downloaded image 958: image_958.jpg
# Downloaded image 959: image_959.jpg
# Downloaded image 960: image_960.jpg
# Downloaded image 961: image_961.jpg
# Downloaded image 962: image_962.jpg
# Downloaded image 963: image_963.jpg
# Downloaded image 964: image_964.jpg
# Downloaded image 965: image_965.jpg
# Downloaded image 966: image_966.jpg
# Downloaded image 967: image_967.jpg
# Downloaded image 968: image_968.jpg
# Downloaded image 969: image_969.jpg
# Downloaded image 970: image_970.jpg
# Downloaded image 971: image_971.jpg
# Downloaded image 972: image_972.jpg
# Downloaded image 973: image_973.jpg
# Downloaded image 974: image_974.jpg
# Downloaded image 975: image_975.jpg
# Downloaded image 976: image_976.jpg
# Downloaded image 977: image_977.jpg
# Downloaded image 978: image_978.jpg
# Downloaded image 979: image_979.jpg
# Downloaded image 980: image_980.jpg
# Downloaded image 981: image_981.jpg
# Downloaded image 982: image_982.jpg
# Downloaded image 983: image_983.jpg
# Downloaded image 984: image_984.jpg
# Downloaded image 985: image_985.jpg
# Downloaded image 986: image_986.jpg
# Downloaded image 987: image_987.jpg
# Downloaded image 988: image_988.jpg
# Downloaded image 989: image_989.jpg
# Downloaded image 990: image_990.jpg
# Downloaded image 991: image_991.jpg
# Downloaded image 992: image_992.jpg
# Downloaded image 993: image_993.jpg
# Downloaded image 994: image_994.jpg
# Downloaded image 995: image_995.jpg
# Downloaded image 996: image_996.jpg
# Downloaded image 997: image_997.jpg
# Downloaded image 998: image_998.jpg
# Downloaded image 999: image_999.jpg
# Downloaded image 1000: image_1000.jpg
# Downloaded image 1001: image_1001.jpg
# Downloaded image 1002: image_1002.jpg
# Downloaded image 1003: image_1003.jpg
# Downloaded image 1004: image_1004.jpg
# Downloaded image 1005: image_1005.jpg
# Downloaded image 1006: image_1006.jpg
# Downloaded image 1007: image_1007.jpg
# Downloaded image 1008: image_1008.jpg
# Downloaded image 1009: image_1009.jpg
# Downloaded image 1010: image_1010.jpg
# Downloaded image 1011: image_1011.jpg
# Downloaded image 1012: image_1012.jpg
# Downloaded image 1013: image_1013.jpg
# Downloaded image 1014: image_1014.jpg
# Downloaded image 1015: image_1015.jpg
# Downloaded image 1016: image_1016.jpg
# Downloaded image 1017: image_1017.jpg
# Downloaded image 1018: image_1018.jpg
# Downloaded image 1019: image_1019.jpg
# Downloaded image 1020: image_1020.jpg
# Downloaded image 1021: image_1021.jpg
# Downloaded image 1022: image_1022.jpg
# Downloaded image 1023: image_1023.jpg
# Downloaded image 1024: image_1024.jpg
# Downloaded image 1025: image_1025.jpg
# Downloaded image 1026: image_1026.jpg
# Downloaded image 1027: image_1027.jpg
# Downloaded image 1028: image_1028.jpg
# Downloaded image 1029: image_1029.jpg
# Downloaded image 1030: image_1030.jpg
# Downloaded image 1031: image_1031.jpg
# Downloaded image 1032: image_1032.jpg
# Downloaded image 1033: image_1033.jpg
# Downloaded image 1034: image_1034.jpg
# Downloaded image 1035: image_1035.jpg
# Downloaded image 1036: image_1036.jpg
# Downloaded image 1037: image_1037.jpg
# Downloaded image 1038: image_1038.jpg
# Downloaded image 1039: image_1039.jpg
# Downloaded image 1040: image_1040.jpg
# Downloaded image 1041: image_1041.jpg
# Downloaded image 1042: image_1042.jpg
# Downloaded image 1043: image_1043.jpg
# Downloaded image 1044: image_1044.jpg
# Downloaded image 1045: image_1045.jpg
# Downloaded image 1046: image_1046.jpg
# Downloaded image 1047: image_1047.jpg
# Downloaded image 1048: image_1048.jpg
# Downloaded image 1049: image_1049.jpg
# Downloaded image 1050: image_1050.jpg
# Downloaded image 1051: image_1051.jpg
# Downloaded image 1052: image_1052.jpg
# Downloaded image 1053: image_1053.jpg
# Downloaded image 1054: image_1054.jpg
# Downloaded image 1055: image_1055.jpg
# Downloaded image 1056: image_1056.jpg
# Downloaded image 1057: image_1057.jpg
# Downloaded image 1058: image_1058.jpg
# Downloaded image 1059: image_1059.jpg
# Downloaded image 1060: image_1060.jpg
# Downloaded image 1061: image_1061.jpg
# Downloaded image 1062: image_1062.jpg
# Downloaded image 1063: image_1063.jpg
# Downloaded image 1064: image_1064.jpg

# %% [markdown]
# ## Renaming Images

# %%
# Reload the image items from folder images
path = "D:\\Projectwork Platform\\AIP-Computer-Vision\\Mobile_Phone_Recognition\\image_collection\\collection1"
img_folder = "val_images"
img_path = os.path.join(path, img_folder)

image_files = os.listdir(img_path)
sorted_files = sorted(image_files, key=lambda x: int(x.split('_')[1].split('.')[0]))

# %%
# Rename image items
def format_item_names(img_path): 
    # code outside for loop block 
    n = 1
    item_list = []
    # code inside for loop block
    for i, item in enumerate(os.listdir(img_path)): 
        # Replace the item number by index number
        seperator = lambda sep: item[item.find(sep):]
        extension = seperator(".")
        formatted_name = f"image_{str(i).zfill(3)}" + extension
        item_list.append(formatted_name)
    
    return item_list

new_item_names = format_item_names(img_path=img_path)
print(f"New item names: {new_item_names[:5]}")
print(f"Number of items: {len(new_item_names)}")

# %%
# Renaming process: modify item names by new formatted names
old_names = sorted(os.listdir(path=img_path), key=lambda x: int(x.split('_')[1].split('.')[0])) # 823
new_names = new_item_names[:]

source_dir = "D:\\Projectwork Platform\\AIP-Computer-Vision\\Mobile_Phone_Recognition\\image_collection\\collection1\\val_images"

img_items = []
for old_name, new_name in zip(old_names, new_names):
    old_file = os.path.join(source_dir, old_name)
    new_file = os.path.join(source_dir, new_name)
    img_items.append(new_file)
    # os.rename(old_file, new_file)
    # print(f"Renamed old name {old_name} --> new name {new_name}")
    print(f"Item {new_name} stored successfully")

# %% [markdown]
# ## Image Storage

# %%
# Save image file names into dataframe
source_path = "D:\\Projectwork Platform\\AIP-Computer-Vision\\Mobile_Phone_Recognition\\image_collection\\collection1\\val_images"

def save_image_into_df(file_num):
    # Define a dataframe
    img_df = pd.DataFrame()
    img_df["Image_URL"] = [os.path.join(path, img) for img in new_item_names]
    img_df["Image_file"] = new_item_names
    img_df.to_csv(f"image{file_num}.csv")
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\P'
# <>:2: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\mian_\AppData\Local\Temp\ipykernel_28040\752021763.py:2: SyntaxWarning: invalid escape sequence '\P'
#   path = "D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images"

# %%
# Save image dataset
save_image_into_df(file_num=1)
