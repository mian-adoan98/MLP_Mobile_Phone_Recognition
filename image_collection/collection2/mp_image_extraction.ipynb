# %% [markdown]
# ## Image Extraction: Amazon Link Page 2

# %%
# import libraries for system configuration
import os
import sys
import warnings

# import dependencies for data processing and visualisation
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# ### Approach: Image Extraction
#
# + Data Loading
# + System Configuration: WebDriver for Edge Browser
# + Collecting Images from Amazon Web page: Downloading Process
# + Renaming image items with new filenames
# + Store image path into DataFrame

# %% [markdown]
# ## Data Loading

# %%
# Load amazon link dataset
amazon_ds = pd.read_csv("links_page1.csv")
amazon_ds.head()
# Out:
#                                                links
# 0  https://www.amazon.com.be/-/en/s?i=electronics...
# 1  https://www.amazon.com.be/-/en/s?i=electronics...
# 2  https://www.amazon.com.be/-/en/s?i=electronics...
# 3  https://www.amazon.com.be/-/en/s?i=electronics...
# 4  https://www.amazon.com.be/-/en/s?i=electronics...

# %%
print(f"Number of links: {amazon_ds.shape[0]}")
# Out:
# Number of links: 52

# %% [markdown]
# ## System Configuration: WebDriver for Edge Browser

# %%
# Import dependencies for extracting images
from selenium import webdriver
from selenium.webdriver.edge.options import Options
from selenium.webdriver.edge.service import Service
from selenium.webdriver.common.by import By

# %%
# Setup environment for WebDriver on Edge Browser
options = Options()
options.add_argument("--headless")

# Setup WebDriver service 
edgedriver_path = "D:\\Data_Engineering\\data_extraction\\msedgedriver.exe"
service = Service(executable_path=edgedriver_path)

driver = webdriver.Edge(options=options, service=service)

# %% [markdown]
# ## Data Collection: Downloading images from Amazon

# %% [markdown]
# The Data Collection process involves several steps of gathering image content for training neural network models. To implement this stage, 2 cases need to be considered. Test Case and Full Case.
#
# The test case assumes 3 URLS extracted from Amazon. This is to get more control on how the images are extracted during the processes. The sequences of images provides more insight about the distribution of the images for every URLs from which the images are downloaded. The full case requires all requested URLs to make a complete image extraction for this stage. This allows more managability of manipulating and storing these images.
#
# This stage entails 2 processes to complete the collection process of images:
# + Extraction Step
# + Downloading Step

# %% [markdown]
# ### Test Case: Extractiing images from 10 URLs

# %% [markdown]
# #### Step 1: Extraction Step

# %%
# Extract images from each amazon links
def extract_images(webdriver, link, class_attr = "s-image") -> list:
    # Retrieve URLS    
    webdriver.get(link)
    img_elements = webdriver.find_elements(By.CLASS_NAME, class_attr)
    image_urls = [web_elem.get_attribute("src") for web_elem in img_elements]
    return image_urls

# Iterate over a list of links --> extract images 
item_img_lst = []
items_tot = 0
for i, link in enumerate(amazon_ds["links"].values[0:3]):
    # Extract images from each amazon weblink + determine the number of images per url
    img_seq = extract_images(webdriver=driver, link=link)
    seq_size = len(img_seq)

    # Store image items into a list + determine the total number of images for the entire list
    item_img_lst.append(img_seq)
    items_tot += seq_size
    print(f"Amazon URL {i + 1}: {seq_size} items (successfully extracted)")
print(f"Image Extraction is completed. Number of Image URLs: {items_tot} ")
# Out:
# Amazon URL 1: 24 items (successfully extracted)
# Amazon URL 2: 24 items (successfully extracted)
# Amazon URL 3: 24 items (successfully extracted)
# Image Extraction is completed. Number of Image URLs: 72

# %%
# Flatten all img sequences into full 1D list of images
img_list = [item for item_seq in item_img_lst for item in item_seq]
img_list[:2]
# Out:
# ['https://m.media-amazon.com/images/I/61w6v4ldYXL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/51jL1Ow6tXL._AC_UL320_.jpg']

# %% [markdown]
# ### Step 2: Downloading Step

# %%
# Import dependencies for downloading images
import requests

# %%
# List of image URLs
image_urls = img_list[:2]

# Folder to save images
path = "D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1"
save_folder = "images"
save_path = os.path.join(path, save_folder)

# Create the folder if it doesn't exist
os.makedirs(save_folder, exist_ok=True)

# Download and save each image
for i, url in enumerate(image_urls, start=1):
    try:
        response = requests.get(url, stream=True)
        response.raise_for_status()  # Check if the request was successful

        # Save the image to the folder
        file_extension = url.split(".")[-1]  # Get the file extension
        file_name = f"image_{i}.{file_extension}"
        file_path = os.path.join(save_path, file_name)

        with open(file_path, "wb") as file:
            for chunk in response.iter_content(1024):
                file.write(chunk)
        
        print(f"Downloaded: {file_path}")
    except requests.exceptions.RequestException as e:
        print(f"Failed to download {url}: {e}")
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\P'
# <>:5: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\mian_\AppData\Local\Temp\ipykernel_28040\2716206488.py:5: SyntaxWarning: invalid escape sequence '\P'
#   path = "D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1"
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_1.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_2.jpg

# %% [markdown]
# ## Full Case: Complete Image Extraction

# %%
# Define functions for: iteration process of image extraction && downloading process
# Function 1: Iteration Image Process
def iteration_image_process(dataset):
    # Define constants
    links = dataset["links"].values
    item_img_lst = []
    items_tot = 0

    # Iterate over a list of links --> extract images 
    for i, link in enumerate(links):
        # Extract images from each amazon weblink + determine the number of images per url
        img_seq = extract_images(webdriver=driver, link=link)
        seq_size = len(img_seq)

        # Store image items into a list + determine the total number of images for the entire list
        item_img_lst.append(img_seq)
        items_tot += seq_size
        print(f"Amazon URL {i + 1}: {seq_size} items (successfully extracted)")
    print(f"Image Extraction is completed. Number of Image URLs: {items_tot} ")
    img_list = [item for item_seq in item_img_lst for item in item_seq]
    return img_list

# Function 2: Downloading process
def downloading_process(image_urls, path):
    # Folder to save images
    save_folder = "images"
    save_path = os.path.join(path, save_folder)

    # Create the folder if it doesn't exist
    os.makedirs(save_folder, exist_ok=True)

    # Download and save each image
    for i, url in enumerate(image_urls, start=1):
        try:
            response = requests.get(url, stream=True)
            response.raise_for_status()  # Check if the request was successful

            # Save the image to the folder
            file_extension = url.split(".")[-1]  # Get the file extension
            file_name = f"image_{i}.{file_extension}"
            file_path = os.path.join(save_path, file_name)

            with open(file_path, "wb") as file:
                for chunk in response.iter_content(1024):
                    file.write(chunk)
            
            print(f"Downloaded image {i}: {file_name}")
        except requests.exceptions.RequestException as e:
            print(f"Failed to download {url}: {e}")

# %%
# Extract all the images from URLs
img_urls = iteration_image_process(amazon_ds)
img_urls[:3]
# Out:
# Amazon URL 1: 24 items (successfully extracted)
# Amazon URL 2: 24 items (successfully extracted)
# Amazon URL 3: 24 items (successfully extracted)
# Amazon URL 4: 24 items (successfully extracted)
# Amazon URL 5: 24 items (successfully extracted)
# Amazon URL 6: 3 items (successfully extracted)
# Amazon URL 7: 3 items (successfully extracted)
# Amazon URL 8: 2 items (successfully extracted)
# Amazon URL 9: 12 items (successfully extracted)
# Amazon URL 10: 3 items (successfully extracted)
# Amazon URL 11: 1 items (successfully extracted)
# Amazon URL 12: 9 items (successfully extracted)
# Amazon URL 13: 4 items (successfully extracted)
# Amazon URL 14: 3 items (successfully extracted)
# Amazon URL 15: 9 items (successfully extracted)
# Amazon URL 16: 18 items (successfully extracted)
# Amazon URL 17: 8 items (successfully extracted)
# Amazon URL 18: 24 items (successfully extracted)
# Amazon URL 19: 24 items (successfully extracted)
# Amazon URL 20: 1 items (successfully extracted)
# Amazon URL 21: 5 items (successfully extracted)
# Amazon URL 22: 4 items (successfully extracted)
# Amazon URL 23: 4 items (successfully extracted)
# Amazon URL 24: 8 items (successfully extracted)
# Amazon URL 25: 3 items (successfully extracted)
# Amazon URL 26: 24 items (successfully extracted)
# Amazon URL 27: 1 items (successfully extracted)
# Amazon URL 28: 16 items (successfully extracted)
# Amazon URL 29: 4 items (successfully extracted)
# Amazon URL 30: 24 items (successfully extracted)
# Amazon URL 31: 20 items (successfully extracted)
# Amazon URL 32: 24 items (successfully extracted)
# Amazon URL 33: 24 items (successfully extracted)
# Amazon URL 34: 24 items (successfully extracted)
# Amazon URL 35: 24 items (successfully extracted)
# Amazon URL 36: 24 items (successfully extracted)
# Amazon URL 37: 24 items (successfully extracted)
# Amazon URL 38: 24 items (successfully extracted)
# Amazon URL 39: 24 items (successfully extracted)
# Amazon URL 40: 24 items (successfully extracted)
# Amazon URL 41: 24 items (successfully extracted)
# Amazon URL 42: 24 items (successfully extracted)
# Amazon URL 43: 2 items (successfully extracted)
# Amazon URL 44: 24 items (successfully extracted)
# Amazon URL 45: 24 items (successfully extracted)
# Amazon URL 46: 24 items (successfully extracted)
# Amazon URL 47: 10 items (successfully extracted)
# Amazon URL 48: 24 items (successfully extracted)
# Amazon URL 49: 24 items (successfully extracted)
# Amazon URL 50: 24 items (successfully extracted)
# Amazon URL 51: 23 items (successfully extracted)
# Amazon URL 52: 24 items (successfully extracted)
# Image Extraction is completed. Number of Image URLs: 824
# ['https://m.media-amazon.com/images/I/51jL1Ow6tXL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/61w6v4ldYXL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71XWNkGrxSS._AC_UL320_.jpg']

# %%
len(img_urls)
# Out:
# 824

# %%
# Download all the images from image URLS in folder called "image"
path = "D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1"
downloading_process(image_urls=img_urls, path=path)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\P'
# <>:2: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\mian_\AppData\Local\Temp\ipykernel_28040\3203005918.py:2: SyntaxWarning: invalid escape sequence '\P'
#   path = "D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1"
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_1.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_2.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_3.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_4.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_5.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_6.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_7.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_8.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_9.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_10.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_11.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_12.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_13.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_14.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_15.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_16.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_17.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_18.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_19.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_20.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_21.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_22.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_23.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_24.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_25.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_26.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_27.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_28.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_29.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_30.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_31.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_32.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_33.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_34.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_35.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_36.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_37.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_38.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_39.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_40.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_41.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_42.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_43.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_44.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_45.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_46.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_47.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_48.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_49.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_50.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_51.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_52.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_53.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_54.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_55.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_56.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_57.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_58.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_59.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_60.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_61.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_62.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_63.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_64.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_65.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_66.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_67.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_68.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_69.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_70.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_71.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_72.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_73.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_74.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_75.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_76.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_77.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_78.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_79.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_80.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_81.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_82.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_83.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_84.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_85.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_86.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_87.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_88.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_89.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_90.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_91.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_92.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_93.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_94.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_95.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_96.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_97.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_98.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_99.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_100.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_101.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_102.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_103.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_104.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_105.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_106.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_107.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_108.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_109.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_110.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_111.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_112.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_113.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_114.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_115.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_116.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_117.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_118.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_119.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_120.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_121.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_122.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_123.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_124.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_125.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_126.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_127.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_128.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_129.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_130.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_131.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_132.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_133.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_134.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_135.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_136.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_137.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_138.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_139.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_140.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_141.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_142.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_143.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_144.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_145.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_146.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_147.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_148.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_149.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_150.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_151.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_152.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_153.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_154.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_155.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_156.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_157.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_158.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_159.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_160.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_161.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_162.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_163.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_164.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_165.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_166.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_167.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_168.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_169.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_170.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_171.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_172.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_173.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_174.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_175.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_176.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_177.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_178.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_179.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_180.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_181.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_182.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_183.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_184.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_185.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_186.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_187.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_188.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_189.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_190.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_191.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_192.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_193.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_194.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_195.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_196.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_197.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_198.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_199.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_200.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_201.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_202.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_203.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_204.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_205.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_206.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_207.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_208.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_209.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_210.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_211.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_212.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_213.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_214.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_215.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_216.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_217.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_218.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_219.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_220.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_221.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_222.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_223.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_224.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_225.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_226.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_227.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_228.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_229.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_230.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_231.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_232.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_233.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_234.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_235.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_236.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_237.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_238.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_239.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_240.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_241.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_242.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_243.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_244.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_245.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_246.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_247.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_248.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_249.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_250.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_251.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_252.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_253.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_254.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_255.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_256.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_257.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_258.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_259.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_260.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_261.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_262.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_263.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_264.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_265.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_266.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_267.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_268.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_269.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_270.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_271.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_272.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_273.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_274.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_275.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_276.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_277.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_278.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_279.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_280.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_281.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_282.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_283.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_284.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_285.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_286.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_287.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_288.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_289.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_290.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_291.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_292.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_293.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_294.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_295.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_296.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_297.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_298.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_299.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_300.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_301.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_302.jpg
# Failed to download https://m.media-amazon.com/images/I/61N3Jesi55L._AC_UL320_.jpg: HTTPSConnectionPool(host='m.media-amazon.com', port=443): Max retries exceeded with url: /images/I/61N3Jesi55L._AC_UL320_.jpg (Caused by SSLError(SSLError(1, '[SSL: DECRYPTION_FAILED_OR_BAD_RECORD_MAC] decryption failed or bad record mac (_ssl.c:1000)')))
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_304.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_305.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_306.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_307.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_308.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_309.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_310.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_311.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_312.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_313.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_314.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_315.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_316.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_317.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_318.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_319.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_320.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_321.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_322.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_323.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_324.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_325.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_326.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_327.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_328.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_329.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_330.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_331.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_332.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_333.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_334.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_335.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_336.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_337.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_338.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_339.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_340.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_341.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_342.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_343.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_344.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_345.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_346.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_347.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_348.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_349.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_350.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_351.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_352.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_353.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_354.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_355.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_356.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_357.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_358.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_359.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_360.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_361.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_362.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_363.jpg
# ...
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_703.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_704.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_705.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_706.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_707.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_708.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_709.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_710.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_711.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_712.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_713.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_714.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_715.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_716.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_717.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_718.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_719.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_720.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_721.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_722.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_723.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_724.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_725.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_726.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_727.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_728.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_729.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_730.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_731.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_732.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_733.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_734.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_735.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_736.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_737.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_738.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_739.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_740.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_741.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_742.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_743.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_744.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_745.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_746.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_747.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_748.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_749.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_750.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_751.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_752.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_753.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_754.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_755.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_756.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_757.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_758.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_759.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_760.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_761.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_762.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_763.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_764.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_765.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_766.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_767.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_768.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_769.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_770.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_771.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_772.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_773.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_774.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_775.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_776.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_777.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_778.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_779.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_780.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_781.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_782.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_783.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_784.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_785.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_786.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_787.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_788.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_789.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_790.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_791.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_792.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_793.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_794.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_795.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_796.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_797.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_798.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_799.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_800.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_801.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_802.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_803.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_804.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_805.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_806.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_807.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_808.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_809.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_810.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_811.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_812.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_813.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_814.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_815.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_816.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_817.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_818.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_819.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_820.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_821.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_822.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_823.jpg
# Downloaded: D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images\image_824.jpg

# %% [markdown]
# ## Renaming Images

# %%
# Reload the image items from folder images
path = "D:\\Projectwork Platform\\AIP-Computer-Vision\\Mobile_Phone_Recognition\\image_collection\\collection1"
img_folder = "val_images"
img_path = os.path.join(path, img_folder)

image_files = os.listdir(img_path)
sorted_files = sorted(image_files, key=lambda x: int(x.split('_')[1].split('.')[0]))

# %%
# Rename image items
def format_item_names(img_path): 
    # code outside for loop block 
    n = 1
    item_list = []
    # code inside for loop block
    for i, item in enumerate(os.listdir(img_path)): 
        # Replace the item number by index number
        seperator = lambda sep: item[item.find(sep):]
        extension = seperator(".")
        formatted_name = f"image_{str(i).zfill(3)}" + extension
        item_list.append(formatted_name)
    
    return item_list

new_item_names = format_item_names(img_path=img_path)
print(f"New item names: {new_item_names[:5]}")
print(f"Number of items: {len(new_item_names)}")

# %%
# Renaming process: modify item names by new formatted names
old_names = sorted(os.listdir(path=img_path), key=lambda x: int(x.split('_')[1].split('.')[0])) # 823
new_names = new_item_names[:]

source_dir = "D:\\Projectwork Platform\\AIP-Computer-Vision\\Mobile_Phone_Recognition\\image_collection\\collection1\\val_images"

img_items = []
for old_name, new_name in zip(old_names, new_names):
    old_file = os.path.join(source_dir, old_name)
    new_file = os.path.join(source_dir, new_name)
    img_items.append(new_file)
    # os.rename(old_file, new_file)
    # print(f"Renamed old name {old_name} --> new name {new_name}")
    print(f"Item {new_name} stored successfully")

# %% [markdown]
# ## Image Storage

# %%
# Save image file names into dataframe
source_path = "D:\\Projectwork Platform\\AIP-Computer-Vision\\Mobile_Phone_Recognition\\image_collection\\collection1\\val_images"

def save_image_into_df(file_num):
    # Define a dataframe
    img_df = pd.DataFrame()
    img_df["Image_URL"] = [os.path.join(path, img) for img in new_item_names]
    img_df["Image_file"] = new_item_names
    img_df.to_csv(f"image{file_num}.csv")
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\P'
# <>:2: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\mian_\AppData\Local\Temp\ipykernel_28040\752021763.py:2: SyntaxWarning: invalid escape sequence '\P'
#   path = "D:\Projectwork Platform\AIP-Computer-Vision\Mobile_Phone_Recognition\image_collection\collection1\images"

# %%
# Save image dataset
save_image_into_df(file_num=1)
